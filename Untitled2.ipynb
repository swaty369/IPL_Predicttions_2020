# %%
names1 = ["Ava", "Emma", "Olivia"]
names2 = ["Olivia", "Sophia", "Emma"]

# %%
def unique_names(names1, names2):
    
    return set(names1+names2)

if __name__ == "__main__":
    names1 = ["Ava", "Emma", "Olivia"]
    names2 = ["Olivia", "Sophia", "Emma"]
    print(unique_names(names1, names2))
# Out:
# {'Ava', 'Sophia', 'Emma', 'Olivia'}

# %%
files = {
        'Input.txt': 'Randy',
        'Code.py': 'Stan',
        'Output.txt': 'Randy'
    }

# %%
files.keys()
# Out:
# dict_keys(['Input.txt', 'Code.py', 'Output.txt'])

# %%
files.values()
new_dic = {}
for k,v in files.items():
    new_dic[v].update(k)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-f0ec4ffe4380> in <module>
#       2 new_dic = {}
#       3 for k,v in files.items():
# ----> 4     new_dic[v].update(k)
#       5
#
# KeyError: 'Randy'

# %%
import numpy as np
import pandas as pd

# %%
res = (list(files.values())) == 'Randy'
res
# Out:
# array([ True, False,  True])

# %%
np.array(list(files.keys()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b620598c93c3> in <module>
# ----> 1 np.array(list(files.keys()))*res
#
# TypeError: ufunc 'multiply' did not contain a loop with signature matching types dtype('<U10') dtype('<U10') dtype('<U10')

# %%
df = pd.DataFrame(files.items())
{i:list(df[df[1]==i][0].values) for i in df[1].unique() }
# Out:
# {'Randy': ['Input.txt', 'Output.txt'], 'Stan': ['Code.py']}

# %%
s = "$>$Python"

s.strip("$>$")
# Out:
# 'Python'

# %%
my_dict = { num:num**2 for num in range(0,10) if num%2==0 }
my_dict
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
s='fox'
s.ljust(4)
# Out:
# 'fox '

# %%
arr = np.array(np.arange(100)).reshape(10,10)
arr[9]
# Out:
# array([90, 91, 92, 93, 94, 95, 96, 97, 98, 99])

# %%
import pandas as pd

a = ('1', ['x', 'y'])
b = ('2', ['d', 't'])

lst = [a, b]
data = dict(lst)

df = pd.DataFrame(data)
df
# Out:
#    1  2
# 0  x  d
# 1  y  t

# %%
class Cat:   
    
    def meow(self):

        return 'meow!'

s = Cat()

s.meow()
# Out:
# 'meow!'

# %%
fruits = {
    'apple': 1,
    'banana': 2,
    'coconut': 3
}

# %%
del fruits['coconut']

# %%
fr
